# %% [markdown]
# # 03_05: Wordplay Challenge Solution

# %%
import math
import collections
import itertools

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
words = sorted({line.strip().lower() for line in open('words.txt', 'r')})

# %%
# code from 03_03_findinganagrams

def signature(word):
    return ''.join(sorted(word))

words_by_sig = collections.defaultdict(set)

for word in words:
    words_by_sig[signature(word)].add(word)
    
anagrams_by_sig = {sig: wordset for sig, wordset in words_by_sig.items() if len(wordset) > 1}

# %%
# reverse word by slicing with negative step 
'michele'[::-1]
# Out:
# 'elehcim'

# %%
# loop over anagram sets, and over all possible pairs of words in each set:
# if the second word equals the reverse of the first, add pair to list

pairs = []

for wordset in anagrams_by_sig.values():
    for word1 in wordset:
        for word2 in wordset:  
            # consider only sorted pairs to avoid duplicate matches
            if word1 >= word2 and word1[::-1] == word2:
                pairs.append((word1, word2))

# %%
pairs
# Out:
# [('ala', 'ala'),
#  ('ama', 'ama'),
#  ('ba', 'ab'),
#  ('aba', 'aba'),
#  ('caba', 'abac'),
#  ('saba', 'abas'),
#  ('bab', 'bab'),
#  ('abba', 'abba'),
#  ('yalb', 'blay'),
#  ('isba', 'absi'),
#  ('tuba', 'abut'),
#  ('araca', 'acara'),
#  ('acca', 'acca'),
#  ('dirca', 'acrid'),
#  ('da', 'ad'),
#  ('dada', 'adad'),
#  ('adda', 'adda'),
#  ('rada', 'adar'),
#  ('dad', 'dad'),
#  ('duad', 'daud'),
#  ('teda', 'adet'),
#  ('naid', 'dian'),
#  ('namda', 'adman'),
#  ('oda', 'ado'),
#  ('yard', 'dray'),
#  ('yad', 'day'),
#  ('ea', 'ae'),
#  ('era', 'are'),
#  ('rea', 'aer'),
#  ('sea', 'aes'),
#  ('alga', 'agla'),
#  ('amaga', 'agama'),
#  ('raga', 'agar'),
#  ('regga', 'agger'),
#  ('biga', 'agib'),
#  ('morga', 'agrom'),
#  ('tsuga', 'agust'),
#  ('ha', 'ah'),
#  ('moha', 'ahom'),
#  ('tha', 'aht'),
#  ('redia', 'aider'),
#  ('elia', 'aile'),
#  ('ima', 'ami'),
#  ('ria', 'air'),
#  ('aria', 'aira'),
#  ('eria', 'aire'),
#  ('ita', 'ati'),
#  ('raja', 'ajar'),
#  ('ka', 'ak'),
#  ('akka', 'akka'),
#  ('oka', 'ako'),
#  ('kua', 'auk'),
#  ('la', 'al'),
#  ('lana', 'anal'),
#  ('lab', 'bal'),
#  ('nabal', 'laban'),
#  ('nabla', 'alban'),
#  ('mela', 'alem'),
#  ('nael', 'lean'),
#  ('lina', 'anil'),
#  ('yalla', 'allay'),
#  ('ella', 'alle'),
#  ('muilla', 'allium'),
#  ('amla', 'alma'),
#  ('lamina', 'animal'),
#  ('dola', 'alod'),
#  ('lowa', 'awol'),
#  ('pal', 'lap'),
#  ('tal', 'lat'),
#  ('ma', 'am'),
#  ('apama', 'amapa'),
#  ('rama', 'amar'),
#  ('diorama', 'amaroid'),
#  ('samas', 'samas'),
#  ('massa', 'assam'),
#  ('enema', 'amene'),
#  ('ulema', 'amelu'),
#  ('mane', 'enam'),
#  ('nema', 'amen'),
#  ('xema', 'amex'),
#  ('decima', 'amiced'),
#  ('lima', 'amil'),
#  ('naim', 'mian'),
#  ('rima', 'amir'),
#  ('maam', 'maam'),
#  ('amma', 'amma'),
#  ('soma', 'amos'),
#  ('tam', 'mat'),
#  ('manuma', 'amunam'),
#  ('yam', 'may'),
#  ('na', 'an'),
#  ('ana', 'ana'),
#  ('aracana', 'anacara'),
#  ('mana', 'anam'),
#  ('nana', 'anan'),
#  ('anna', 'anna'),
#  ('asana', 'anasa'),
#  ('tana', 'anat'),
#  ('yana', 'anay'),
#  ('edna', 'ande'),
#  ('rogan', 'nagor'),
#  ('sina', 'anis'),
#  ('sain', 'nias'),
#  ('nan', 'nan'),
#  ('manna', 'annam'),
#  ('nona', 'anon'),
#  ('tan', 'nat'),
#  ('taen', 'neat'),
#  ('etna', 'ante'),
#  ('tuan', 'naut'),
#  ('yan', 'nay'),
#  ('trapa', 'apart'),
#  ('dopa', 'apod'),
#  ('tap', 'pat'),
#  ('supa', 'apus'),
#  ('ra', 'ar'),
#  ('bara', 'arab'),
#  ('read', 'daer'),
#  ('sagra', 'argas'),
#  ('regal', 'lager'),
#  ('rail', 'liar'),
#  ('rial', 'lair'),
#  ('lira', 'aril'),
#  ('kra', 'ark'),
#  ('ram', 'mar'),
#  ('ran', 'nar'),
#  ('ora', 'aro'),
#  ('sarra', 'arras'),
#  ('tracer', 'recart'),
#  ('sirrah', 'harris'),
#  ('tar', 'rat'),
#  ('tra', 'art'),
#  ('sumatra', 'artamus'),
#  ('ura', 'aru'),
#  ('mura', 'arum'),
#  ('yar', 'ray'),
#  ('rayan', 'nayar'),
#  ('lyra', 'aryl'),
#  ('sa', 'as'),
#  ('asa', 'asa'),
#  ('kasa', 'asak'),
#  ('mesa', 'asem'),
#  ('sark', 'kras'),
#  ('rosa', 'asor'),
#  ('ta', 'at'),
#  ('ata', 'ata'),
#  ('pata', 'atap'),
#  ('tae', 'eat'),
#  ('eta', 'ate'),
#  ('seta', 'ates'),
#  ('pita', 'atip'),
#  ('sita', 'atis'),
#  ('salta', 'atlas'),
#  ('teal', 'laet'),
#  ('tael', 'leat'),
#  ('lakota', 'atokal'),
#  ('laud', 'dual'),
#  ('ulua', 'aulu'),
#  ('etua', 'aute'),
#  ('lava', 'aval'),
#  ('eva', 'ave'),
#  ('diva', 'avid'),
#  ('siva', 'avis'),
#  ('ova', 'avo'),
#  ('wa', 'aw'),
#  ('tawa', 'awat'),
#  ('wad', 'daw'),
#  ('wan', 'naw'),
#  ('noxa', 'axon'),
#  ('ya', 'ay'),
#  ('haya', 'ayah'),
#  ('cab', 'bac'),
#  ('dab', 'bad'),
#  ('gab', 'bag'),
#  ('mab', 'bam'),
#  ('nab', 'ban'),
#  ('knab', 'bank'),
#  ('rab', 'bar'),
#  ('brab', 'barb'),
#  ('drab', 'bard'),
#  ('sab', 'bas'),
#  ('stab', 'bats'),
#  ('tab', 'bat'),
#  ('kitab', 'batik'),
#  ('wab', 'baw'),
#  ('deb', 'bed'),
#  ('dieb', 'beid'),
#  ('treble', 'elbert'),
#  ('neb', 'ben'),
#  ('reb', 'ber'),
#  ('dib', 'bid'),
#  ('gib', 'big'),
#  ('mib', 'bim'),
#  ('nib', 'bin'),
#  ('drib', 'bird'),
#  ('sib', 'bis'),
#  ('tib', 'bit'),
#  ('bulb', 'blub'),
#  ('cabob', 'bobac'),
#  ('boob', 'boob'),
#  ('dob', 'bod'),
#  ('doob', 'bood'),
#  ('gob', 'bog'),
#  ('rohob', 'bohor'),
#  ('obol', 'lobo'),
#  ('mob', 'bom'),
#  ('nob', 'bon'),
#  ('knob', 'bonk'),
#  ('pob', 'bop'),
#  ('rob', 'bor'),
#  ('rerob', 'borer'),
#  ('gorb', 'brog'),
#  ('sob', 'bos'),
#  ('wob', 'bow'),
#  ('garb', 'brag'),
#  ('yarb', 'bray'),
#  ('yerb', 'brey'),
#  ('turb', 'brut'),
#  ('trub', 'burt'),
#  ('tuber', 'rebut'),
#  ('dub', 'bud'),
#  ('nub', 'bun'),
#  ('knub', 'bunk'),
#  ('rub', 'bur'),
#  ('drub', 'burd'),
#  ('grub', 'burg'),
#  ('rubor', 'robur'),
#  ('suber', 'rebus'),
#  ('sub', 'bus'),
#  ('tub', 'but'),
#  ('ecad', 'dace'),
#  ('lac', 'cal'),
#  ('mac', 'cam'),
#  ('sumac', 'camus'),
#  ('pac', 'cap'),
#  ('paced', 'decap'),
#  ('recap', 'pacer'),
#  ('wac', 'caw'),
#  ('spec', 'ceps'),
#  ('tic', 'cit'),
#  ('talc', 'clat'),
#  ('laced', 'decal'),
#  ('doc', 'cod'),
#  ('roc', 'cor'),
#  ('orc', 'cro'),
#  ('soc', 'cos'),
#  ('marc', 'cram'),
#  ('eruc', 'cure'),
#  ('gad', 'dag'),
#  ('sgad', 'dags'),
#  ('had', 'dah'),
#  ('laid', 'dial'),
#  ('radek', 'kedar'),
#  ('lad', 'dal'),
#  ('mad', 'dam'),
#  ('nomad', 'damon'),
#  ('nidal', 'ladin'),
#  ('pad', 'dap'),
#  ('rad', 'dar'),
#  ('farad', 'daraf'),
#  ('grad', 'darg'),
#  ('ranid', 'dinar'),
#  ('strad', 'darts'),
#  ('retrad', 'darter'),
#  ('trader', 'redart'),
#  ('sad', 'das'),
#  ('rated', 'detar'),
#  ('ed', 'de'),
#  ('meed', 'deem'),
#  ('peed', 'deep'),
#  ('reed', 'deer'),
#  ('ged', 'deg'),
#  ('led', 'del'),
#  ('fled', 'delf'),
#  ('timed', 'demit'),
#  ('ned', 'den'),
#  ('hoped', 'depoh'),
#  ('tressed', 'dessert'),
#  ('leud', 'duel'),
#  ('lived', 'devil'),
#  ('wed', 'dew'),
#  ('rewed', 'dewer'),
#  ('yed', 'dey'),
#  ('id', 'di'),
#  ('morbid', 'dibrom'),
#  ('reid', 'dier'),
#  ('tide', 'edit'),
#  ('gid', 'dig'),
#  ('olid', 'dilo'),
#  ('mid', 'dim'),
#  ('timid', 'dimit'),
#  ('nid', 'din'),
#  ('enid', 'dine'),
#  ('sid', 'dis'),
#  ('tid', 'dit'),
#  ('od', 'do'),
#  ('dod', 'dod'),
#  ('ode', 'edo'),
#  ('god', 'dog'),
#  ('lod', 'dol'),
#  ('elod', 'dole'),
#  ('mod', 'dom'),
#  ('nod', 'don'),
#  ('lood', 'dool'),
#  ('mood', 'doom'),
#  ('redoom', 'mooder'),
#  ('rood', 'door'),
#  ('pod', 'dop'),
#  ('rod', 'dor'),
#  ('prod', 'dorp'),
#  ('sod', 'dos'),
#  ('tod', 'dot'),
#  ('wod', 'dow'),
#  ('liard', 'drail'),
#  ('ward', 'draw'),
#  ('reward', 'drawer'),
#  ('warder', 'redraw'),
#  ('word', 'drow'),
#  ('gud', 'dug'),
#  ('mud', 'dum'),
#  ('pud', 'dup'),
#  ('nae', 'ean'),
#  ('notice', 'eciton'),
#  ('lee', 'eel'),
#  ('ree', 'eer'),
#  ('ere', 'ere'),
#  ('loge', 'egol'),
#  ('he', 'eh'),
#  ('eke', 'eke'),
#  ('spale', 'elaps'),
#  ('nifle', 'elfin'),
#  ('haole', 'eloah'),
#  ('lone', 'enol'),
#  ('noel', 'leon'),
#  ('spole', 'elops'),
#  ('seel', 'lees'),
#  ('revel', 'lever'),
#  ('me', 'em'),
#  ('lime', 'emil'),
#  ('mime', 'emim'),
#  ('rime', 'emir'),
#  ('remi', 'imer'),
#  ('time', 'emit'),
#  ('mem', 'mem'),
#  ('ume', 'emu'),
#  ('ne', 'en'),
#  ('romane', 'enamor'),
#  ('reman', 'namer'),
#  ('fine', 'enif'),
#  ('wone', 'enow'),
#  ('esne', 'ense'),
#  ('yoven', 'nevoy'),
#  ('sope', 'epos'),
#  ('re', 'er'),
#  ('reg', 'ger'),
#  ('reen', 'neer'),
#  ('sore', 'eros'),
#  ('retier', 'reiter'),
#  ('seer', 'rees'),
#  ('se', 'es'),
#  ('nave', 'evan'),
#  ('eve', 'eve'),
#  ('neve', 'even'),
#  ('reve', 'ever'),
#  ('live', 'evil'),
#  ('ewe', 'ewe'),
#  ('ye', 'ey'),
#  ('eye', 'eye'),
#  ('nye', 'eyn'),
#  ('raif', 'fiar'),
#  ('reef', 'feer'),
#  ('lief', 'feil'),
#  ('nef', 'fen'),
#  ('if', 'fi'),
#  ('gif', 'fig'),
#  ('welf', 'flew'),
#  ('golf', 'flog'),
#  ('wolf', 'flow'),
#  ('wolfer', 'reflow'),
#  ('of', 'fo'),
#  ('ofo', 'ofo'),
#  ('loof', 'fool'),
#  ('stoof', 'foots'),
#  ('orf', 'fro'),
#  ('refer', 'refer'),
#  ('jag', 'gaj'),
#  ('lag', 'gal'),
#  ('mag', 'gam'),
#  ('nag', 'gan'),
#  ('nagnag', 'gangan'),
#  ('tang', 'gnat'),
#  ('rag', 'gar'),
#  ('rang', 'gnar'),
#  ('sag', 'gas'),
#  ('tag', 'gat'),
#  ('retag', 'gater'),
#  ('wag', 'gaw'),
#  ('wang', 'gnaw'),
#  ('zag', 'gaz'),
#  ('leg', 'gel'),
#  ('redleg', 'gelder'),
#  ('meg', 'gem'),
#  ('seg', 'ges'),
#  ('teg', 'get'),
#  ('mig', 'gim'),
#  ('nig', 'gin'),
#  ('pig', 'gip'),
#  ('trig', 'girt'),
#  ('tig', 'git'),
#  ('og', 'go'),
#  ('log', 'gol'),
#  ('reflog', 'golfer'),
#  ('nog', 'gon'),
#  ('rog', 'gor'),
#  ('sog', 'gos'),
#  ('tog', 'got'),
#  ('upgo', 'ogpu'),
#  ('lug', 'gul'),
#  ('plug', 'gulp'),
#  ('mug', 'gum'),
#  ('pug', 'gup'),
#  ('rug', 'gur'),
#  ('trug', 'gurt'),
#  ('tug', 'gut'),
#  ('makah', 'hakam'),
#  ('nallah', 'hallan'),
#  ('mah', 'ham'),
#  ('pah', 'hap'),
#  ('trah', 'hart'),
#  ('wah', 'haw'),
#  ('yah', 'hay'),
#  ('reh', 'her'),
#  ('oh', 'ho'),
#  ('pooh', 'hoop'),
#  ('poh', 'hop'),
#  ('obi', 'ibo'),
#  ('immi', 'immi'),
#  ('ni', 'in'),
#  ('retin', 'niter'),
#  ('tennis', 'sinnet'),
#  ('nori', 'iron'),
#  ('kori', 'irok'),
#  ('si', 'is'),
#  ('sisi', 'isis'),
#  ('ti', 'it'),
#  ('neti', 'iten'),
#  ('tier', 'reit'),
#  ('timo', 'omit'),
#  ('raj', 'jar'),
#  ('taj', 'jat'),
#  ('nak', 'kan'),
#  ('panak', 'kanap'),
#  ('tanak', 'kanat'),
#  ('lark', 'kral'),
#  ('yak', 'kay'),
#  ('kayak', 'kayak'),
#  ('leek', 'keel'),
#  ('peek', 'keep'),
#  ('seek', 'kees'),
#  ('pik', 'kip'),
#  ('polk', 'klop'),
#  ('pank', 'knap'),
#  ('rank', 'knar'),
#  ('nark', 'kran'),
#  ('tink', 'knit'),
#  ('tonk', 'knot'),
#  ('tunk', 'knut'),
#  ('ok', 'ko'),
#  ('rok', 'kor'),
#  ('sok', 'kos'),
#  ('rauk', 'kuar'),
#  ('mal', 'lam'),
#  ('nopal', 'lapon'),
#  ('plap', 'palp'),
#  ('sural', 'larus'),
#  ('sal', 'las'),
#  ('sail', 'lias'),
#  ('ossal', 'lasso'),
#  ('peel', 'leep'),
#  ('reel', 'leer'),
#  ('teel', 'leet'),
#  ('repel', 'leper'),
#  ('relap', 'paler'),
#  ('rel', 'ler'),
#  ('relevel', 'leveler'),
#  ('rivel', 'levir'),
#  ('neil', 'lien'),
#  ('mil', 'lim'),
#  ('nil', 'lin'),
#  ('noil', 'lion'),
#  ('sunil', 'linus'),
#  ('sil', 'lis'),
#  ('til', 'lit'),
#  ('well', 'llew'),
#  ('olam', 'malo'),
#  ('siol', 'lois'),
#  ('mool', 'loom'),
#  ('pool', 'loop'),
#  ('tool', 'loot'),
#  ('retool', 'looter'),
#  ('pol', 'lop'),
#  ('tol', 'lot'),
#  ('owl', 'lwo'),
#  ('nam', 'man'),
#  ('senam', 'manes'),
#  ('oam', 'mao'),
#  ('pam', 'map'),
#  ('tram', 'mart'),
#  ('sam', 'mas'),
#  ('stam', 'mats'),
#  ('teem', 'meet'),
#  ('teemer', 'remeet'),
#  ('timer', 'remit'),
#  ('retem', 'meter'),
#  ('wem', 'mew'),
#  ('ohm', 'mho'),
#  ('saim', 'mias'),
#  ('nim', 'min'),
#  ('rim', 'mir'),
#  ('om', 'mo'),
#  ('sloom', 'mools'),
#  ('room', 'moor'),
#  ('toom', 'moot'),
#  ('pom', 'mop'),
#  ('tom', 'mot'),
#  ('yom', 'moy'),
#  ('um', 'mu'),
#  ('sum', 'mus'),
#  ('ym', 'my'),
#  ('rohan', 'nahor'),
#  ('zaman', 'namaz'),
#  ('pan', 'nap'),
#  ('susan', 'nasus'),
#  ('redden', 'nedder'),
#  ('peen', 'neep'),
#  ('teen', 'neet'),
#  ('pen', 'nep'),
#  ('repen', 'neper'),
#  ('ten', 'net'),
#  ('oven', 'nevo'),
#  ('wen', 'new'),
#  ('pin', 'nip'),
#  ('tin', 'nit'),
#  ('on', 'no'),
#  ('tenon', 'nonet'),
#  ('poon', 'noop'),
#  ('ron', 'nor'),
#  ('ton', 'not'),
#  ('won', 'now'),
#  ('yon', 'noy'),
#  ('un', 'nu'),
#  ('tun', 'nut'),
#  ('tao', 'oat'),
#  ('senones', 'senones'),
#  ('top', 'pot'),
#  ('ro', 'or'),
#  ('tor', 'rot'),
#  ('yor', 'roy'),
#  ('so', 'os'),
#  ('oto', 'oto'),
#  ('otto', 'otto'),
#  ('toot', 'toot'),
#  ('suto', 'otus'),
#  ('wo', 'ow'),
#  ('repaper', 'repaper'),
#  ('rap', 'par'),
#  ('trap', 'part'),
#  ('tarp', 'prat'),
#  ('taps', 'spat'),
#  ('wap', 'paw'),
#  ('yap', 'pay'),
#  ('rep', 'per'),
#  ('rip', 'pir'),
#  ('tip', 'pit'),
#  ('pulp', 'plup'),
#  ('toop', 'poot'),
#  ('troper', 'report'),
#  ('tops', 'spot'),
#  ('toper', 'repot'),
#  ('wop', 'pow'),
#  ('turp', 'prut'),
#  ('up', 'pu'),
#  ('sup', 'pus'),
#  ('tup', 'put'),
#  ('sar', 'ras'),
#  ('war', 'raw'),
#  ('rewarder', 'redrawer'),
#  ('teer', 'reet'),
#  ('sier', 'reis'),
#  ('tinker', 'reknit'),
#  ('tenner', 'rennet'),
#  ('terret', 'terret'),
#  ('retter', 'retter'),
#  ('rever', 'rever'),
#  ('tewer', 'rewet'),
#  ('venator', 'rotanev'),
#  ('sur', 'rus'),
#  ('tur', 'rut'),
#  ('was', 'saw'),
#  ('taws', 'swat'),
#  ('twas', 'sawt'),
#  ('yas', 'say'),
#  ('wes', 'sew'),
#  ('yes', 'sey'),
#  ('sis', 'sis'),
#  ('wels', 'slew'),
#  ('wots', 'stow'),
#  ('traps', 'spart'),
#  ('sus', 'sus'),
#  ('tuts', 'stut'),
#  ('yaws', 'sway'),
#  ('vat', 'tav'),
#  ('wat', 'taw'),
#  ('yat', 'tay'),
#  ('teet', 'teet'),
#  ('wet', 'tew'),
#  ('trot', 'tort'),
#  ('wot', 'tow'),
#  ('yot', 'toy'),
#  ('wort', 'trow'),
#  ('ut', 'tu'),
#  ('yaw', 'way'),
#  ('yew', 'wey'),
#  ('yow', 'woy')]

# %%
import itertools

# %%
# list all combinations of two different elements from the set {1,2,3} 
list(itertools.combinations({1,2,3}, 2))

# %%
# same as above, using itertools.combinations to generate unique pairs

pairs = []

for  in anagrams_by_sig.values():
    for word1, word2 in itertools.combinations(wordset, 2):
        if word1[::-1] == word2:
            pairs.append((word1, word2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17252/3215259926.py in <module>
#       3 pairs = []
#       4
# ----> 5 for wordset in anagrams_by_sig.values():
#       6     for word1, word2 in itertools.combinations(wordset, 2):
#       7         if word1[::-1] == word2:
#
# NameError: name 'anagrams_by_sig' is not defined

# %%
pairs
# Out:
# []
