# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
words = sorted({line.strip().lower() for line in open('words.txt', 'r')})

# %%
r = 'reward'
d = 'drawer'

# %%
r ==
# Out:
# True

# %%
def findPalindrome(word):
    palinofword = d[::-1]
    return (word in words and palinofword in words),palinofword

# findPalindrome('top')

# %%
words_by_palndrone = collections.defaultdict(set)

for word in words:
    flag,palinofword = findPalindrome(word)
    if flag:
        print(flag,word)
        words_by_palndrone[word].add(palinofword)
# Out:
# True a
# True aa
# True ab
# True aba
# True abac
# True abas
# True abba
# True absi
# True abut
# True acara
# True acca
# True acrid
# True ad
# True ada
# True adad
# True adar
# True adda
# True adet
# True adinida
# True adman
# True ado
# True ae
# True aer
# True aes
# True affa
# True aga
# True agama
# True agar
# True agger
# True agib
# True agla
# True agrom
# True agust
# True ah
# True aha
# True ahom
# True aht
# True aider
# True aile
# True air
# True aira
# True aire
# True ajaja
# True ajar
# True ak
# True aka
# True akka
# True ako
# True al
# True ala
# True alala
# True alban
# True alem
# True alga
# True allay
# True alle
# True allium
# True alma
# True alod
# True alula
# True am
# True ama
# True amaga
# True amapa
# True amar
# True amaroid
# True amelu
# True amen
# True amene
# True amex
# True ami
# True amiced
# True amil
# True amir
# True amla
# True amma
# True amos
# True amunam
# True an
# True ana
# True anacara
# True anal
# True anam
# True anan
# True anana
# True anasa
# True anat
# True anay
# True ande
# True anil
# True animal
# True anis
# True anna
# True annam
# True anon
# True ante
# True apa
# True apama
# True apart
# True apod
# True apus
# True ar
# True ara
# True arab
# True araca
# True aracana
# True arara
# True are
# True argas
# True aria
# True aril
# True ark
# True aro
# True arras
# True art
# True artamus
# True aru
# True arum
# True aryl
# True as
# True asa
# True asak
# True asana
# True asem
# True asor
# True assam
# True at
# True ata
# True atap
# True ate
# True ates
# True ati
# True atip
# True atis
# True atlas
# True atokal
# True atta
# True auk
# True aulu
# True aute
# True ava
# True aval
# True ave
# True avid
# True avis
# True avo
# True aw
# True awa
# True awat
# True awol
# True axon
# True ay
# True ayah
# True b
# True ba
# True bab
# True bac
# True bad
# True bag
# True bal
# True bam
# True ban
# True bank
# True bar
# True bara
# True barb
# True bard
# True bas
# True bat
# True batik
# True bats
# True baw
# True bed
# True beid
# True ben
# True ber
# True bib
# True bid
# True big
# True biga
# True bim
# True bin
# True bird
# True bis
# True bit
# True blay
# True blub
# True bob
# True bobac
# True bod
# True bog
# True bohor
# True bom
# True bon
# True bonk
# True boob
# True bood
# True bop
# True bor
# True borer
# True bos
# True bow
# True brab
# True brag
# True bray
# True brey
# True brog
# True brut
# True bub
# True bud
# True bulb
# True bun
# True bunk
# True bur
# True burd
# True burg
# True burt
# True bus
# True but
# True c
# True cab
# True caba
# True cabob
# True cal
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17976/2924906379.py in <module>
#       2
#       3 for word in words:
# ----> 4     flag,palinofword = findPalindrome(word)
#       5     if flag:
#       6         print(flag,word)
#
# KeyboardInterrupt:

# %%
words_by_palndrone
