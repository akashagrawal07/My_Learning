# %% [markdown]
# # SCI-KIT LEARN

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
type(boston)
# Out:
# sklearn.utils.Bunch

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
type(boston['data'])
# Out:
# numpy.ndarray

# %%
boston['feature_names']
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
print(boston['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of black people by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
clf = RandomForestRegressor()

# %%
clf.fit(boston['data'],boston['target'])
# Out:
# RandomForestRegressor()

# %%
clf.score(boston['data'],boston['target'])
# Out:
# 0.9831427098486915

# %%
clf.n_features_
# Out:
# 13

# %%
boston['data'].shape
# Out:
# (506, 13)

# %%
row = boston['data'][17]
row.shape
# Out:
# (13,)

# %%
row.reshape(-1,13)
# Out:
# array([[  0.7842,   0.    ,   8.14  ,   0.    ,   0.538 ,   5.99  ,
#          81.7   ,   4.2579,   4.    , 307.    ,  21.    , 386.75  ,
#          14.67  ]])

# %%
clf.predict(row.reshape(-1,13))
# Out:
# array([17.57])

# %%
boston['target'][17]
# Out:
# 17.5

# %% [markdown]
# #### Understand Train / test splits

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(boston['data'],boston['target'],test_size=0.3)

# %%
clf = RandomForestRegressor()
clf.fit(x_train,y_train)
clf.score(x_test,y_test)
# Out:
# 0.7724460792284656

# %% [markdown]
# #### Preprocess data

# %%
import pandas as pd

# %%
df = pd.DataFrame(boston['data'],columns=boston['feature_names'])
print(df.max(axis=0))
# Out:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# dtype: float64

# %%
from sklearn.svm import SVR

# %%
clf = SVR()
clf.fit(x_train,y_train)
clf.score(x_test,y_test)
# Out:
# 0.13607212578801497

# %%
from sklearn import preprocessing

# %%
xs = preprocessing.scale(boston['data'])
df = pd.DataFrame(boston['data'],columns=boston['feature_names'])
print(df.max(axis=0))
# Out:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# dtype: float64

# %%
xs_train,xs_test,ys_train,ys_test = train_test_split(xs,boston['target'],test_size=0.3)

# %%
clf = SVR()
clf.fit(x_train,y_train)
clf.score(x_test,y_test)
# Out:
# 0.13607212578801497

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=5)
pca.fit(boston['data'])
# Out:
# PCA(n_components=5)

# %%
xp = pca.transform(boston['data'])
xp.shape
# Out:
# (506, 5)

# %% [markdown]
# #### Compose Pipelines

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline([
    ('scale',StandardScaler()),
    ('pca',PCA(n_components=4)),
    ('svr',SVR()),
])

# %%
from sklearn.datasets import load_boston
import pandas as pd

# %%
boston = load_boston()

# %%
df = pd.DataFrame(boston['data'],columns=boston['feature_names'])
df['price'] = boston['target']

# %%
hdf = df.head(10)
hdf
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2
# 5     18.7  394.12   5.21   28.7
# 6     15.2  395.60  12.43   22.9
# 7     15.2  396.90  19.15   27.1
# 8     15.2  386.63  29.93   16.5
# 9     15.2  386.71  17.10   18.9

# %%
hdf.style.highlight_max()
# Out:
# <style type="text/css">
# #T_04bbc_row0_col1, #T_04bbc_row0_col3, #T_04bbc_row0_col4, #T_04bbc_row0_col11, #T_04bbc_row1_col3, #T_04bbc_row1_col11, #T_04bbc_row2_col3, #T_04bbc_row2_col5, #T_04bbc_row3_col3, #T_04bbc_row3_col10, #T_04bbc_row4_col3, #T_04bbc_row4_col10, #T_04bbc_row4_col11, #T_04bbc_row4_col13, #T_04bbc_row5_col3, #T_04bbc_row5_col10, #T_04bbc_row6_col2, #T_04bbc_row6_col3, #T_04bbc_row6_col8, #T_04bbc_row6_col9, #T_04bbc_row7_col2, #T_04bbc_row7_col3, #T_04bbc_row7_col8, #T_04bbc_row7_col9, #T_04bbc_row7_col11, #T_04bbc_row8_col0, #T_04bbc_row8_col2, #T_04bbc_row8_col3, #T_04bbc_row8_col6, #T_04bbc_row8_col8, #T_04bbc_row8_col9, #T_04bbc_row8_col12, #T_04bbc_row9_col2, #T_04bbc_row9_col3, #T_04bbc_row9_col7, #T_04bbc_row9_col8, #T_04bbc_row9_col9 {
#   background-color: yellow;
# }
# </style>
# <table id="T_04bbc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CRIM</th>
#       <th class="col_heading level0 col1" >ZN</th>
#       <th class="col_heading level0 col2" >INDUS</th>
#       <th class="col_heading level0 col3" >CHAS</th>
#       <th class="col_heading level0 col4" >NOX</th>
#       <th class="col_heading level0 col5" >RM</th>
#       <th class="col_heading level0 col6" >AGE</th>
#       <th class="col_heading level0 col7" >DIS</th>
#       <th class="col_heading level0 col8" >RAD</th>
#       <th class="col_heading level0 col9" >TAX</th>
#       <th class="col_heading level0 col10" >PTRATIO</th>
#       <th class="col_heading level0 col11" >B</th>
#       <th class="col_heading level0 col12" >LSTAT</th>
#       <th class="col_heading level0 col13" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04bbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04bbc_row0_col0" class="data row0 col0" >0.006320</td>
#       <td id="T_04bbc_row0_col1" class="data row0 col1" >18.000000</td>
#       <td id="T_04bbc_row0_col2" class="data row0 col2" >2.310000</td>
#       <td id="T_04bbc_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_04bbc_row0_col4" class="data row0 col4" >0.538000</td>
#       <td id="T_04bbc_row0_col5" class="data row0 col5" >6.575000</td>
#       <td id="T_04bbc_row0_col6" class="data row0 col6" >65.200000</td>
#       <td id="T_04bbc_row0_col7" class="data row0 col7" >4.090000</td>
#       <td id="T_04bbc_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_04bbc_row0_col9" class="data row0 col9" >296.000000</td>
#       <td id="T_04bbc_row0_col10" class="data row0 col10" >15.300000</td>
#       <td id="T_04bbc_row0_col11" class="data row0 col11" >396.900000</td>
#       <td id="T_04bbc_row0_col12" class="data row0 col12" >4.980000</td>
#       <td id="T_04bbc_row0_col13" class="data row0 col13" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_04bbc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04bbc_row1_col0" class="data row1 col0" >0.027310</td>
#       <td id="T_04bbc_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_04bbc_row1_col2" class="data row1 col2" >7.070000</td>
#       <td id="T_04bbc_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_04bbc_row1_col4" class="data row1 col4" >0.469000</td>
#       <td id="T_04bbc_row1_col5" class="data row1 col5" >6.421000</td>
#       <td id="T_04bbc_row1_col6" class="data row1 col6" >78.900000</td>
#       <td id="T_04bbc_row1_col7" class="data row1 col7" >4.967100</td>
#       <td id="T_04bbc_row1_col8" class="data row1 col8" >2.000000</td>
#       <td id="T_04bbc_row1_col9" class="data row1 col9" >242.000000</td>
#       <td id="T_04bbc_row1_col10" class="data row1 col10" >17.800000</td>
#       <td id="T_04bbc_row1_col11" class="data row1 col11" >396.900000</td>
#       <td id="T_04bbc_row1_col12" class="data row1 col12" >9.140000</td>
#       <td id="T_04bbc_row1_col13" class="data row1 col13" >21.600000</td>
#     </tr>
#     <tr>
#       <th id="T_04bbc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_04bbc_row2_col0" class="data row2 col0" >0.027290</td>
#       <td id="T_04bbc_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_04bbc_row2_col2" class="data row2 col2" >7.070000</td>
#       <td id="T_04bbc_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_04bbc_row2_col4" class="data row2 col4" >0.469000</td>
#       <td id="T_04bbc_row2_col5" class="data row2 col5" >7.185000</td>
#       <td id="T_04bbc_row2_col6" class="data row2 col6" >61.100000</td>
#       <td id="T_04bbc_row2_col7" class="data row2 col7" >4.967100</td>
#       <td id="T_04bbc_row2_col8" class="data row2 col8" >2.000000</td>
#       <td id="T_04bbc_row2_col9" class="data row2 col9" >242.000000</td>
#       <td id="T_04bbc_row2_col10" class="data row2 col10" >17.800000</td>
#       <td id="T_04bbc_row2_col11" class="data row2 col11" >392.830000</td>
#       <td id="T_04bbc_row2_col12" class="data row2 col12" >4.030000</td>
#       <td id="T_04bbc_row2_col13" class="data row2 col13" >34.700000</td>
#     </tr>
#     <tr>
#       <th id="T_04bbc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_04bbc_row3_col0" class="data row3 col0" >0.032370</td>
#       <td id="T_04bbc_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_04bbc_row3_col2" class="data row3 col2" >2.180000</td>
#       <td id="T_04bbc_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_04bbc_row3_col4" class="data row3 col4" >0.458000</td>
#       <td id="T_04bbc_row3_col5" class="data row3 col5" >6.998000</td>
#       <td id="T_04bbc_row3_col6" class="data row3 col6" >45.800000</td>
#       <td id="T_04bbc_row3_col7" class="data row3 col7" >6.062200</td>
#       <td id="T_04bbc_row3_col8" class="data row3 col8" >3.000000</td>
#       <td id="T_04bbc_row3_col9" class="data row3 col9" >222.000000</td>
#       <td id="T_04bbc_row3_col10" class="data row3 col10" >18.700000</td>
#       <td id="T_04bbc_row3_col11" class="data row3 col11" >394.630000</td>
#       <td id="T_04bbc_row3_col12" class="data row3 col12" >2.940000</td>
#       <td id="T_04bbc_row3_col13" class="data row3 col13" >33.400000</td>
#     </tr>
#     <tr>
#       <th id="T_04bbc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_04bbc_row4_col0" class="data row4 col0" >0.069050</td>
#       <td id="T_04bbc_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_04bbc_row4_col2" class="data row4 col2" >2.180000</td>
#       <td id="T_04bbc_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_04bbc_row4_col4" class="data row4 col4" >0.458000</td>
#       <td id="T_04bbc_row4_col5" class="data row4 col5" >7.147000</td>
#       <td id="T_04bbc_row4_col6" class="data row4 col6" >54.200000</td>
#       <td id="T_04bbc_row4_col7" class="data row4 col7" >6.062200</td>
#       <td id="T_04bbc_row4_col8" class="data row4 col8" >3.000000</td>
#       <td id="T_04bbc_row4_col9" class="data row4 col9" >222.000000</td>
#       <td id="T_04bbc_row4_col10" class="data row4 col10" >18.700000</td>
#       <td id="T_04bbc_row4_col11" class="data row4 col11" >396.900000</td>
#       <td id="T_04bbc_row4_col12" class="data row4 col12" >5.330000</td>
#       <td id="T_04bbc_row4_col13" class="data row4 col13" >36.200000</td>
#     </tr>
#     <tr>
#       <th id="T_04bbc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_04bbc_row5_col0" class="data row5 col0" >0.029850</td>
#       <td id="T_04bbc_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_04bbc_row5_col2" class="data row5 col2" >2.180000</td>
#       <td id="T_04bbc_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_04bbc_row5_col4" class="data row5 col4" >0.458000</td>
#       <td id="T_04bbc_row5_col5" class="data row5 col5" >6.430000</td>
#       <td id="T_04bbc_row5_col6" class="data row5 col6" >58.700000</td>
#       <td id="T_04bbc_row5_col7" class="data row5 col7" >6.062200</td>
#       <td id="T_04bbc_row5_col8" class="data row5 col8" >3.000000</td>
#       <td id="T_04bbc_row5_col9" class="data row5 col9" >222.000000</td>
#       <td id="T_04

# %%
hdf.style.background_gradient()
# Out:
# <style type="text/css">
# #T_be4f1_row0_col0, #T_be4f1_row0_col3, #T_be4f1_row0_col7, #T_be4f1_row0_col8, #T_be4f1_row1_col1, #T_be4f1_row1_col3, #T_be4f1_row2_col1, #T_be4f1_row2_col3, #T_be4f1_row3_col1, #T_be4f1_row3_col2, #T_be4f1_row3_col3, #T_be4f1_row3_col4, #T_be4f1_row3_col6, #T_be4f1_row3_col9, #T_be4f1_row3_col12, #T_be4f1_row4_col1, #T_be4f1_row4_col2, #T_be4f1_row4_col3, #T_be4f1_row4_col4, #T_be4f1_row4_col9, #T_be4f1_row5_col1, #T_be4f1_row5_col2, #T_be4f1_row5_col3, #T_be4f1_row5_col4, #T_be4f1_row5_col9, #T_be4f1_row6_col3, #T_be4f1_row6_col10, #T_be4f1_row7_col3, #T_be4f1_row7_col10, #T_be4f1_row8_col3, #T_be4f1_row8_col5, #T_be4f1_row8_col10, #T_be4f1_row8_col11, #T_be4f1_row8_col13, #T_be4f1_row9_col3, #T_be4f1_row9_col10 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_be4f1_row0_col1, #T_be4f1_row0_col4, #T_be4f1_row0_col11, #T_be4f1_row1_col11, #T_be4f1_row2_col5, #T_be4f1_row3_col10, #T_be4f1_row4_col10, #T_be4f1_row4_col11, #T_be4f1_row4_col13, #T_be4f1_row5_col10, #T_be4f1_row6_col2, #T_be4f1_row6_col8, #T_be4f1_row6_col9, #T_be4f1_row7_col2, #T_be4f1_row7_col8, #T_be4f1_row7_col9, #T_be4f1_row7_col11, #T_be4f1_row8_col0, #T_be4f1_row8_col2, #T_be4f1_row8_col6, #T_be4f1_row8_col8, #T_be4f1_row8_col9, #T_be4f1_row8_col12, #T_be4f1_row9_col2, #T_be4f1_row9_col7, #T_be4f1_row9_col8, #T_be4f1_row9_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_be4f1_row0_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_be4f1_row0_col5 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_be4f1_row0_col6 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_be4f1_row0_col9 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_be4f1_row0_col10 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_be4f1_row0_col12 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_be4f1_row0_col13 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_be4f1_row1_col0, #T_be4f1_row2_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_be4f1_row1_col2, #T_be4f1_row2_col2 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_be4f1_row1_col4, #T_be4f1_row2_col4 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_be4f1_row1_col5 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_be4f1_row1_col6 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_be4f1_row1_col7, #T_be4f1_row2_col7, #T_be4f1_row7_col5 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_be4f1_row1_col8, #T_be4f1_row2_col8 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_be4f1_row1_col9, #T_be4f1_row2_col9 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_be4f1_row1_col10, #T_be4f1_row2_col10, #T_be4f1_row7_col7 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_be4f1_row1_col12 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_be4f1_row1_col13 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_be4f1_row2_col6 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_be4f1_row2_col11 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_be4f1_row2_col12 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_be4f1_row2_col13 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_be4f1_row3_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_be4f1_row3_col5 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_be4f1_row3_col7, #T_be4f1_row4_col7, #T_be4f1_row5_col7 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_be4f1_row3_col8, #T_be4f1_row4_col8, #T_be4f1_row5_col8 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_be4f1_row3_col11 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_be4f1_row3_col13 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_be4f1_row4_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_be4f1_row4_col5 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_be4f1_row4_col6 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_be4f1_row4_col12, #T_be4f1_row5_col12 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_be4f1_row5_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_be4f1_row5_col5 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_be4f1_row5_col6 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_be4f1_row5_col11 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_be4f1_row5_col13 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_be4f1_row6_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_be4f1_row6_col1, #T_be4f1_row7_col1, #T_be4f1_row8_col1, #T_be4f1_row9_col1 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_be4f1_row6_col4, #T_be4f1_row7_col4, #T_be4f1_row8_col4, #T_be4f1_row9_col4 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_be4f1_row6_col5 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_be4f1_row6_col6 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_be4f1_row6_col7 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_be4f1_row6_col11 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_be4f1_row6_col12 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_be4f1_row6_col13 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_be4f1_row7_col0 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_be4f1_row7_col6 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_be4f1_row7_col12 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_be4f1_row7_col13 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_be4f1_row8_col7 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_be4f1_row9_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_be4f1_row9_col5 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_be4f1_row9_col6 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_be4f1_row9_col11 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_be4f1_row9_col12 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_be4f1_row9_col13 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# </style>
# <table id="T_be4f1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CRIM</th>
#       <th class="col_heading level0 col1" >ZN</th>
#       <th class="col_heading level0 col2" >INDUS</th>
#       <th class="col_heading level0 col3" >CHAS</th>
#       <th class="col_heading level0 col4" >NOX</th>
#       <th class="col_heading level0 col5" >RM</th>
#       <th class="col_heading level0 col6" >AGE</th>
#       <th class="col_heading level0 col7" >DIS</th>
#       <th class="col_heading level0 col8" >RAD</th>
#       <th class="col_heading level0 col9" >TAX</th>
#       <th class="col_heading level0 col10" >PTRATIO</th>
#       <th class="col_heading level0 col11" >B</th>
#       <th class="col_heading level0 col12" >LSTAT</th>
#       <th class="col_heading level0 col13" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be4f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be4f1_row0_col0" class="data row0 col0" >0.006320</td>
#       <td id="T_be4f1_row0_col1" class="data row0 col1" >18.000000</td>
#       <td id="T_be4f1_row0_col2" class="data row0 col2" >2.310000</td>
#       <td id="T_be4f1_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_be4f1_row0_col4" class="data row0 col4" >0.538000</td>
#       <td id="T_be4f1_row0_col5" class="data row0 col5" >6.575000</td>
#       <td id="T_be4f1_row0_col6" class="data row0 col6" >65.200000</td>
#       <td id="T_be4f1_row0_col7" class="data row0 col7" >4.090000</td>
#       <td id="T_be4f1_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_be4f1_row0_col9" class="data row0 col9" >296.000000</td>
#       <td id="T_be4f1_row0_col10" class="data row0 col10" >15.300000</td>
#       <td id="T_be4f1_row0_col11" class="data row0 col11" >396.900000</td>
#       <td id="T_be4f1_row0_col12" class="data row0 col12" >4.980000</td>
#       <td id="T_be4f1_row0_col13" class="data row0 col13" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_be4f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be4f1_row1_col0" class="data row1 col0" >0.027310</td>
#       <td id="T_be4f1_row1_col1" class="data row1 col1" >0.000

# %%
hdf.style.bar()
# Out:
# <style type="text/css">
# #T_0b6ae_row0_col0, #T_0b6ae_row0_col3, #T_0b6ae_row0_col7, #T_0b6ae_row0_col8, #T_0b6ae_row1_col1, #T_0b6ae_row1_col3, #T_0b6ae_row2_col1, #T_0b6ae_row2_col3, #T_0b6ae_row3_col1, #T_0b6ae_row3_col2, #T_0b6ae_row3_col3, #T_0b6ae_row3_col4, #T_0b6ae_row3_col6, #T_0b6ae_row3_col9, #T_0b6ae_row3_col12, #T_0b6ae_row4_col1, #T_0b6ae_row4_col2, #T_0b6ae_row4_col3, #T_0b6ae_row4_col4, #T_0b6ae_row4_col9, #T_0b6ae_row5_col1, #T_0b6ae_row5_col2, #T_0b6ae_row5_col3, #T_0b6ae_row5_col4, #T_0b6ae_row5_col9, #T_0b6ae_row6_col3, #T_0b6ae_row6_col10, #T_0b6ae_row7_col3, #T_0b6ae_row7_col10, #T_0b6ae_row8_col3, #T_0b6ae_row8_col5, #T_0b6ae_row8_col10, #T_0b6ae_row8_col11, #T_0b6ae_row8_col13, #T_0b6ae_row9_col3, #T_0b6ae_row9_col10 {
#   width: 10em;
#   height: 80%;
# }
# #T_0b6ae_row0_col1, #T_0b6ae_row0_col4, #T_0b6ae_row0_col11, #T_0b6ae_row1_col11, #T_0b6ae_row2_col5, #T_0b6ae_row3_col10, #T_0b6ae_row4_col10, #T_0b6ae_row4_col11, #T_0b6ae_row4_col13, #T_0b6ae_row5_col10, #T_0b6ae_row6_col2, #T_0b6ae_row6_col8, #T_0b6ae_row6_col9, #T_0b6ae_row7_col2, #T_0b6ae_row7_col8, #T_0b6ae_row7_col9, #T_0b6ae_row7_col11, #T_0b6ae_row8_col0, #T_0b6ae_row8_col2, #T_0b6ae_row8_col6, #T_0b6ae_row8_col8, #T_0b6ae_row8_col9, #T_0b6ae_row8_col12, #T_0b6ae_row9_col2, #T_0b6ae_row9_col7, #T_0b6ae_row9_col8, #T_0b6ae_row9_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_0b6ae_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.3%, transparent 2.3%);
# }
# #T_0b6ae_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 60.7%, transparent 60.7%);
# }
# #T_0b6ae_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.8%, transparent 35.8%);
# }
# #T_0b6ae_row0_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 83.1%, transparent 83.1%);
# }
# #T_0b6ae_row0_col10 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.9%, transparent 2.9%);
# }
# #T_0b6ae_row0_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 7.6%, transparent 7.6%);
# }
# #T_0b6ae_row0_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 38.1%, transparent 38.1%);
# }
# #T_0b6ae_row1_col0, #T_0b6ae_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.2%, transparent 10.2%);
# }
# #T_0b6ae_row1_col2, #T_0b6ae_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 85.9%, transparent 85.9%);
# }
# #T_0b6ae_row1_col4, #T_0b6ae_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.7%, transparent 13.7%);
# }
# #T_0b6ae_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 50.8%, transparent 50.8%);
# }
# #T_0b6ae_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 61.1%, transparent 61.1%);
# }
# #T_0b6ae_row1_col7, #T_0b6ae_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.1%, transparent 35.1%);
# }
# #T_0b6ae_row1_col8, #T_0b6ae_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.0%, transparent 25.0%);
# }
# #T_0b6ae_row1_col9, #T_0b6ae_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 22.5%, transparent 22.5%);
# }
# #T_0b6ae_row1_col10, #T_0b6ae_row2_col10 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 74.3%, transparent 74.3%);
# }
# #T_0b6ae_row1_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 23.0%, transparent 23.0%);
# }
# #T_0b6ae_row1_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.9%, transparent 25.9%);
# }
# #T_0b6ae_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 28.2%, transparent 28.2%);
# }
# #T_0b6ae_row2_col11 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 60.4%, transparent 60.4%);
# }
# #T_0b6ae_row2_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.0%, transparent 4.0%);
# }
# #T_0b6ae_row2_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 92.4%, transparent 92.4%);
# }
# #T_0b6ae_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 12.7%, transparent 12.7%);
# }
# #T_0b6ae_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 88.0%, transparent 88.0%);
# }
# #T_0b6ae_row3_col7, #T_0b6ae_row4_col7, #T_0b6ae_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 78.8%, transparent 78.8%);
# }
# #T_0b6ae_row3_col8, #T_0b6ae_row4_col8, #T_0b6ae_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 50.0%, transparent 50.0%);
# }
# #T_0b6ae_row3_col11 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 77.9%, transparent 77.9%);
# }
# #T_0b6ae_row3_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 85.8%, transparent 85.8%);
# }
# #T_0b6ae_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 30.6%, transparent 30.6%);
# }
# #T_0b6ae_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 97.6%, transparent 97.6%);
# }
# #T_0b6ae_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.5%, transparent 15.5%);
# }
# #T_0b6ae_row4_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 8.9%, transparent 8.9%);
# }
# #T_0b6ae_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.5%, transparent 11.5%);
# }
# #T_0b6ae_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 51.4%, transparent 51.4%);
# }
# #T_0b6ae_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 23.8%, transparent 23.8%);
# }
# #T_0b6ae_row5_col11 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 72.9%, transparent 72.9%);
# }
# #T_0b6ae_row5_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 8.4%, transparent 8.4%);
# }
# #T_0b6ae_row5_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 61.9%, transparent 61.9%);
# }
# #T_0b6ae_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 40.0%, transparent 40.0%);
# }
# #T_0b6ae_row6_col1, #T_0b6ae_row7_col1, #T_0b6ae_row8_col1, #T_0b6ae_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 69.4%, transparent 69.4%);
# }
# #T_0b6ae_row6_col4, #T_0b6ae_row7_col4, #T_0b6ae_row8_col4, #T_0b6ae_row9_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 82.5%, transparent 82.5%);
# }
# #T_0b6ae_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 24.5%, transparent 24.5%);
# }
# #T_0b6ae_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 38.4%, transparent 38.4%);
# }
# #T_0b6ae_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 58.8%, transparent 58.8%);
# }
# #T_0b6ae_row6_col11 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 87.3%, transparent 87.3%);
# }
# #T_0b6ae_row6_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.2%, transparent 35.2%);
# }
# #T_0b6ae_row6_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.5%, transparent 32.5%);
# }
# #T_0b6ae_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 67.5%, transparent 67.5%);
# }
# #T_0b6ae_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.8%, transparent 34.8%);
# }
# #T_0b6ae_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 92.8%, transparent 92.8%);
# }
# #T_0b6ae_row7_

# %%
def odd_green(val):
    if val %2 != 0:
        return 'color:green'
    return ''

# %%
hdf.style.applymap(odd_green)
# Out:
# <style type="text/css">
# #T_5f358_row0_col0, #T_5f358_row0_col2, #T_5f358_row0_col4, #T_5f358_row0_col5, #T_5f358_row0_col6, #T_5f358_row0_col7, #T_5f358_row0_col8, #T_5f358_row0_col10, #T_5f358_row0_col11, #T_5f358_row0_col12, #T_5f358_row1_col0, #T_5f358_row1_col2, #T_5f358_row1_col4, #T_5f358_row1_col5, #T_5f358_row1_col6, #T_5f358_row1_col7, #T_5f358_row1_col10, #T_5f358_row1_col11, #T_5f358_row1_col12, #T_5f358_row1_col13, #T_5f358_row2_col0, #T_5f358_row2_col2, #T_5f358_row2_col4, #T_5f358_row2_col5, #T_5f358_row2_col6, #T_5f358_row2_col7, #T_5f358_row2_col10, #T_5f358_row2_col11, #T_5f358_row2_col12, #T_5f358_row2_col13, #T_5f358_row3_col0, #T_5f358_row3_col2, #T_5f358_row3_col4, #T_5f358_row3_col5, #T_5f358_row3_col6, #T_5f358_row3_col7, #T_5f358_row3_col8, #T_5f358_row3_col10, #T_5f358_row3_col11, #T_5f358_row3_col12, #T_5f358_row3_col13, #T_5f358_row4_col0, #T_5f358_row4_col2, #T_5f358_row4_col4, #T_5f358_row4_col5, #T_5f358_row4_col6, #T_5f358_row4_col7, #T_5f358_row4_col8, #T_5f358_row4_col10, #T_5f358_row4_col11, #T_5f358_row4_col12, #T_5f358_row4_col13, #T_5f358_row5_col0, #T_5f358_row5_col2, #T_5f358_row5_col4, #T_5f358_row5_col5, #T_5f358_row5_col6, #T_5f358_row5_col7, #T_5f358_row5_col8, #T_5f358_row5_col10, #T_5f358_row5_col11, #T_5f358_row5_col12, #T_5f358_row5_col13, #T_5f358_row6_col0, #T_5f358_row6_col1, #T_5f358_row6_col2, #T_5f358_row6_col4, #T_5f358_row6_col5, #T_5f358_row6_col6, #T_5f358_row6_col7, #T_5f358_row6_col8, #T_5f358_row6_col9, #T_5f358_row6_col10, #T_5f358_row6_col11, #T_5f358_row6_col12, #T_5f358_row6_col13, #T_5f358_row7_col0, #T_5f358_row7_col1, #T_5f358_row7_col2, #T_5f358_row7_col4, #T_5f358_row7_col5, #T_5f358_row7_col6, #T_5f358_row7_col7, #T_5f358_row7_col8, #T_5f358_row7_col9, #T_5f358_row7_col10, #T_5f358_row7_col11, #T_5f358_row7_col12, #T_5f358_row7_col13, #T_5f358_row8_col0, #T_5f358_row8_col1, #T_5f358_row8_col2, #T_5f358_row8_col4, #T_5f358_row8_col5, #T_5f358_row8_col7, #T_5f358_row8_col8, #T_5f358_row8_col9, #T_5f358_row8_col10, #T_5f358_row8_col11, #T_5f358_row8_col12, #T_5f358_row8_col13, #T_5f358_row9_col0, #T_5f358_row9_col1, #T_5f358_row9_col2, #T_5f358_row9_col4, #T_5f358_row9_col5, #T_5f358_row9_col6, #T_5f358_row9_col7, #T_5f358_row9_col8, #T_5f358_row9_col9, #T_5f358_row9_col10, #T_5f358_row9_col11, #T_5f358_row9_col12, #T_5f358_row9_col13 {
#   color: green;
# }
# </style>
# <table id="T_5f358_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CRIM</th>
#       <th class="col_heading level0 col1" >ZN</th>
#       <th class="col_heading level0 col2" >INDUS</th>
#       <th class="col_heading level0 col3" >CHAS</th>
#       <th class="col_heading level0 col4" >NOX</th>
#       <th class="col_heading level0 col5" >RM</th>
#       <th class="col_heading level0 col6" >AGE</th>
#       <th class="col_heading level0 col7" >DIS</th>
#       <th class="col_heading level0 col8" >RAD</th>
#       <th class="col_heading level0 col9" >TAX</th>
#       <th class="col_heading level0 col10" >PTRATIO</th>
#       <th class="col_heading level0 col11" >B</th>
#       <th class="col_heading level0 col12" >LSTAT</th>
#       <th class="col_heading level0 col13" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f358_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f358_row0_col0" class="data row0 col0" >0.006320</td>
#       <td id="T_5f358_row0_col1" class="data row0 col1" >18.000000</td>
#       <td id="T_5f358_row0_col2" class="data row0 col2" >2.310000</td>
#       <td id="T_5f358_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_5f358_row0_col4" class="data row0 col4" >0.538000</td>
#       <td id="T_5f358_row0_col5" class="data row0 col5" >6.575000</td>
#       <td id="T_5f358_row0_col6" class="data row0 col6" >65.200000</td>
#       <td id="T_5f358_row0_col7" class="data row0 col7" >4.090000</td>
#       <td id="T_5f358_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_5f358_row0_col9" class="data row0 col9" >296.000000</td>
#       <td id="T_5f358_row0_col10" class="data row0 col10" >15.300000</td>
#       <td id="T_5f358_row0_col11" class="data row0 col11" >396.900000</td>
#       <td id="T_5f358_row0_col12" class="data row0 col12" >4.980000</td>
#       <td id="T_5f358_row0_col13" class="data row0 col13" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f358_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f358_row1_col0" class="data row1 col0" >0.027310</td>
#       <td id="T_5f358_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_5f358_row1_col2" class="data row1 col2" >7.070000</td>
#       <td id="T_5f358_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_5f358_row1_col4" class="data row1 col4" >0.469000</td>
#       <td id="T_5f358_row1_col5" class="data row1 col5" >6.421000</td>
#       <td id="T_5f358_row1_col6" class="data row1 col6" >78.900000</td>
#       <td id="T_5f358_row1_col7" class="data row1 col7" >4.967100</td>
#       <td id="T_5f358_row1_col8" class="data row1 col8" >2.000000</td>
#       <td id="T_5f358_row1_col9" class="data row1 col9" >242.000000</td>
#       <td id="T_5f358_row1_col10" class="data row1 col10" >17.800000</td>
#       <td id="T_5f358_row1_col11" class="data row1 col11" >396.900000</td>
#       <td id="T_5f358_row1_col12" class="data row1 col12" >9.140000</td>
#       <td id="T_5f358_row1_col13" class="data row1 col13" >21.600000</td>
#     </tr>
#     <tr>
#       <th id="T_5f358_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5f358_row2_col0" class="data row2 col0" >0.027290</td>
#       <td id="T_5f358_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_5f358_row2_col2" class="data row2 col2" >7.070000</td>
#       <td id="T_5f358_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_5f358_row2_col4" class="data row2 col4" >0.469000</td>
#       <td id="T_5f358_row2_col5" class="data row2 col5" >7.185000</td>
#       <td id="T_5f358_row2_col6" class="data row2 col6" >61.100000</td>
#       <td id="T_5f358_row2_col7" class="data row2 col7" >4.967100</td>
#       <td id="T_5f358_row2_col8" class="data row2 col8" >2.000000</td>
#       <td id="T_5f358_row2_col9" class="data row2 col9" >242.000000</td>
#       <td id="T_5f358_row2_col10" class="data row2 col10" >17.800000</td>
#       <td id="T_5f358_row2_col11" class="data row2 col11" >392.830000</td>
#       <td id="T_5f358_row2_col12" class="data row2 col12" >4.030000</td>
#       <td id="T_5f358_row2_col13" class="data row2 col13" >34.700000</td>
#     </tr>
#     <tr>
#       <th id="T_5f358_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5f358_row3_col0" class="data row3 col0" >0.032370</td>
#       <td id="T_5f358_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_5f358_row3_col2" class="data row3 col2" >2.180000</td>
#       <td id="T_5f358_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_5f358_row3_col4" class="data row3 col4" >0.458000</td>
#       <td id="T_5f358_row3_col5" class="data row3 col5" >6.998000</td>
#       <td id="T_5f358_row3_col6" class="data row3 col6" >45.800000</td>
#       <td id="T_5f358_row3_col7" class="data row3 col7" >6.062200</td>
#       <td id="T_5f358_row3_col8" class="data row3 col8" >3.000000</td>
#       <td id="T_5f358_row3_col9" class="data row3 col9" >222.000000</td>
#       <td id="T_5f358_row3_col10" class="data row3 col10" >18.700000</td>
#       <td id="T_5f358_row3_col11" class="data row3 col11" >394.630000</td>
#       <td id="T_5f358_row3_col12" class="data row3 col12" >2.940000</td>
#       <td id="T_5f358_row3_col13" class="data row3 col13" >33.400000</td>
#     </tr>
#     <tr>
#       <th id="T_5f358_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5f358_row4_col0" class="data row4 col0" >0.069050</td>
#       <td id="T_5f358_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_5f358_row4_col2" class="data row4 col2" >2.180000</td>
#       <td id="T_5f358_row4_col3" class="data row4 col3" >0.0000

# %%
def orange10(val):
    if val  > 10:
        return 'background-color:orange'
    return ''

# %%
hdf.style.applymap(odd_green).applymap(orange10)
# Out:
# <style type="text/css">
# #T_a7a0b_row0_col0, #T_a7a0b_row0_col2, #T_a7a0b_row0_col4, #T_a7a0b_row0_col5, #T_a7a0b_row0_col7, #T_a7a0b_row0_col8, #T_a7a0b_row0_col12, #T_a7a0b_row1_col0, #T_a7a0b_row1_col2, #T_a7a0b_row1_col4, #T_a7a0b_row1_col5, #T_a7a0b_row1_col7, #T_a7a0b_row1_col12, #T_a7a0b_row2_col0, #T_a7a0b_row2_col2, #T_a7a0b_row2_col4, #T_a7a0b_row2_col5, #T_a7a0b_row2_col7, #T_a7a0b_row2_col12, #T_a7a0b_row3_col0, #T_a7a0b_row3_col2, #T_a7a0b_row3_col4, #T_a7a0b_row3_col5, #T_a7a0b_row3_col7, #T_a7a0b_row3_col8, #T_a7a0b_row3_col12, #T_a7a0b_row4_col0, #T_a7a0b_row4_col2, #T_a7a0b_row4_col4, #T_a7a0b_row4_col5, #T_a7a0b_row4_col7, #T_a7a0b_row4_col8, #T_a7a0b_row4_col12, #T_a7a0b_row5_col0, #T_a7a0b_row5_col2, #T_a7a0b_row5_col4, #T_a7a0b_row5_col5, #T_a7a0b_row5_col7, #T_a7a0b_row5_col8, #T_a7a0b_row5_col12, #T_a7a0b_row6_col0, #T_a7a0b_row6_col2, #T_a7a0b_row6_col4, #T_a7a0b_row6_col5, #T_a7a0b_row6_col7, #T_a7a0b_row6_col8, #T_a7a0b_row7_col0, #T_a7a0b_row7_col2, #T_a7a0b_row7_col4, #T_a7a0b_row7_col5, #T_a7a0b_row7_col7, #T_a7a0b_row7_col8, #T_a7a0b_row8_col0, #T_a7a0b_row8_col2, #T_a7a0b_row8_col4, #T_a7a0b_row8_col5, #T_a7a0b_row8_col7, #T_a7a0b_row8_col8, #T_a7a0b_row9_col0, #T_a7a0b_row9_col2, #T_a7a0b_row9_col4, #T_a7a0b_row9_col5, #T_a7a0b_row9_col7, #T_a7a0b_row9_col8 {
#   color: green;
# }
# #T_a7a0b_row0_col1, #T_a7a0b_row0_col9, #T_a7a0b_row0_col13, #T_a7a0b_row1_col9, #T_a7a0b_row2_col9, #T_a7a0b_row3_col9, #T_a7a0b_row4_col9, #T_a7a0b_row5_col9, #T_a7a0b_row8_col6 {
#   background-color: orange;
# }
# #T_a7a0b_row0_col6, #T_a7a0b_row0_col10, #T_a7a0b_row0_col11, #T_a7a0b_row1_col6, #T_a7a0b_row1_col10, #T_a7a0b_row1_col11, #T_a7a0b_row1_col13, #T_a7a0b_row2_col6, #T_a7a0b_row2_col10, #T_a7a0b_row2_col11, #T_a7a0b_row2_col13, #T_a7a0b_row3_col6, #T_a7a0b_row3_col10, #T_a7a0b_row3_col11, #T_a7a0b_row3_col13, #T_a7a0b_row4_col6, #T_a7a0b_row4_col10, #T_a7a0b_row4_col11, #T_a7a0b_row4_col13, #T_a7a0b_row5_col6, #T_a7a0b_row5_col10, #T_a7a0b_row5_col11, #T_a7a0b_row5_col13, #T_a7a0b_row6_col1, #T_a7a0b_row6_col6, #T_a7a0b_row6_col9, #T_a7a0b_row6_col10, #T_a7a0b_row6_col11, #T_a7a0b_row6_col12, #T_a7a0b_row6_col13, #T_a7a0b_row7_col1, #T_a7a0b_row7_col6, #T_a7a0b_row7_col9, #T_a7a0b_row7_col10, #T_a7a0b_row7_col11, #T_a7a0b_row7_col12, #T_a7a0b_row7_col13, #T_a7a0b_row8_col1, #T_a7a0b_row8_col9, #T_a7a0b_row8_col10, #T_a7a0b_row8_col11, #T_a7a0b_row8_col12, #T_a7a0b_row8_col13, #T_a7a0b_row9_col1, #T_a7a0b_row9_col6, #T_a7a0b_row9_col9, #T_a7a0b_row9_col10, #T_a7a0b_row9_col11, #T_a7a0b_row9_col12, #T_a7a0b_row9_col13 {
#   color: green;
#   background-color: orange;
# }
# </style>
# <table id="T_a7a0b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CRIM</th>
#       <th class="col_heading level0 col1" >ZN</th>
#       <th class="col_heading level0 col2" >INDUS</th>
#       <th class="col_heading level0 col3" >CHAS</th>
#       <th class="col_heading level0 col4" >NOX</th>
#       <th class="col_heading level0 col5" >RM</th>
#       <th class="col_heading level0 col6" >AGE</th>
#       <th class="col_heading level0 col7" >DIS</th>
#       <th class="col_heading level0 col8" >RAD</th>
#       <th class="col_heading level0 col9" >TAX</th>
#       <th class="col_heading level0 col10" >PTRATIO</th>
#       <th class="col_heading level0 col11" >B</th>
#       <th class="col_heading level0 col12" >LSTAT</th>
#       <th class="col_heading level0 col13" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7a0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7a0b_row0_col0" class="data row0 col0" >0.006320</td>
#       <td id="T_a7a0b_row0_col1" class="data row0 col1" >18.000000</td>
#       <td id="T_a7a0b_row0_col2" class="data row0 col2" >2.310000</td>
#       <td id="T_a7a0b_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_a7a0b_row0_col4" class="data row0 col4" >0.538000</td>
#       <td id="T_a7a0b_row0_col5" class="data row0 col5" >6.575000</td>
#       <td id="T_a7a0b_row0_col6" class="data row0 col6" >65.200000</td>
#       <td id="T_a7a0b_row0_col7" class="data row0 col7" >4.090000</td>
#       <td id="T_a7a0b_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_a7a0b_row0_col9" class="data row0 col9" >296.000000</td>
#       <td id="T_a7a0b_row0_col10" class="data row0 col10" >15.300000</td>
#       <td id="T_a7a0b_row0_col11" class="data row0 col11" >396.900000</td>
#       <td id="T_a7a0b_row0_col12" class="data row0 col12" >4.980000</td>
#       <td id="T_a7a0b_row0_col13" class="data row0 col13" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a7a0b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7a0b_row1_col0" class="data row1 col0" >0.027310</td>
#       <td id="T_a7a0b_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_a7a0b_row1_col2" class="data row1 col2" >7.070000</td>
#       <td id="T_a7a0b_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_a7a0b_row1_col4" class="data row1 col4" >0.469000</td>
#       <td id="T_a7a0b_row1_col5" class="data row1 col5" >6.421000</td>
#       <td id="T_a7a0b_row1_col6" class="data row1 col6" >78.900000</td>
#       <td id="T_a7a0b_row1_col7" class="data row1 col7" >4.967100</td>
#       <td id="T_a7a0b_row1_col8" class="data row1 col8" >2.000000</td>
#       <td id="T_a7a0b_row1_col9" class="data row1 col9" >242.000000</td>
#       <td id="T_a7a0b_row1_col10" class="data row1 col10" >17.800000</td>
#       <td id="T_a7a0b_row1_col11" class="data row1 col11" >396.900000</td>
#       <td id="T_a7a0b_row1_col12" class="data row1 col12" >9.140000</td>
#       <td id="T_a7a0b_row1_col13" class="data row1 col13" >21.600000</td>
#     </tr>
#     <tr>
#       <th id="T_a7a0b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a7a0b_row2_col0" class="data row2 col0" >0.027290</td>
#       <td id="T_a7a0b_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_a7a0b_row2_col2" class="data row2 col2" >7.070000</td>
#       <td id="T_a7a0b_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_a7a0b_row2_col4" class="data row2 col4" >0.469000</td>
#       <td id="T_a7a0b_row2_col5" class="data row2 col5" >7.185000</td>
#       <td id="T_a7a0b_row2_col6" class="data row2 col6" >61.100000</td>
#       <td id="T_a7a0b_row2_col7" class="data row2 col7" >4.967100</td>
#       <td id="T_a7a0b_row2_col8" class="data row2 col8" >2.000000</td>
#       <td id="T_a7a0b_row2_col9" class="data row2 col9" >242.000000</td>
#       <td id="T_a7a0b_row2_col10" class="data row2 col10" >17.800000</td>
#       <td id="T_a7a0b_row2_col11" class="data row2 col11" >392.830000</td>
#       <td id="T_a7a0b_row2_col12" class="data row2 col12" >4.030000</td>
#       <td id="T_a7a0b_row2_col13" class="data row2 col13" >34.700000</td>
#     </tr>
#     <tr>
#       <th id="T_a7a0b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a7a0b_row3_col0" class="data row3 col0" >0.032370</td>
#       <td id="T_a7a0b_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_a7a0b_row3_col2" class="data row3 col2" >2.180000</td>
#       <td id="T_a7a0b_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_a7a0b_row3_col4" class="data row3 col4" >0.458000</td>
#       <td id="T_a7a0b_row3_col5" class="data row3 col5" >6.998000</td>
#       <td id="T_a7a0b_row3_col6" class="data row3 col6" >45.800000</td>
#       <td id="T_a7a0b_row3_col7" class="data row3 col7" >6.062200</td>
#       <td id="T_a7a0b_row3_col8" class="data row3 col8" >3.000000</td>
#       <td id="T_a7a0b_row3_col9" class="data row3 col9" >222.000000</td>
#       <td id="T_a7a0b_row3_col10" class="data row3 col10" >18.700000</td>
#       <td id="T_a7a0b_row3_col11" class="data row3 col11" >394.630000</td>
#       <td id="T_a7a0b_row3_col12" class="data row3 col12" >2.940000</td>
#       <td id="T_a7a0b_row3_col13" class="data row3 col13" >33.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a7a0b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17652/3618078849.py in <module>
# ----> 1 import qgrid
#
# ModuleNotFoundError: No module named 'qgrid'
